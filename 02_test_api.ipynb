# %%
import pandas as pd
import numpy as np
import pickle as pk
import category_encoders as ce
from sklearn  import preprocessing

import requests
import json

# %%
datas = pd.read_csv("./datas/test_feature_engineering.csv")
datas.drop("Unnamed: 0", axis=1, inplace=True)
datas
# Out:
#       CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0               0             1                0             1
# 1               1             0                1             0
# 2               1             0                1             1
# 3               1             0                1             1
# 4               1             1                0             1
# ...           ...           ...              ...           ...
# 4795            0             1                0             0
# 4796            1             0                0             0
# 4797            1             0                1             0
# 4798            0             1                0             0
# 4799            1             0                1             0
#
#       AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             108000.0    265536.0      12901.5         180000.0
# 1             279000.0    787131.0      26145.0         679500.0
# ...

# %%
model = pk.load(open("./model/model.pkl", "rb"))
# Out:
# Modèle non trouvé

# %%
predict = model.predict_proba([datas.iloc[3]])
print(predict)
# Out:
# [[0.84131102 0.15868898]]

# %%
if predict[:,1] >= 0.4669:
    print ("prediction: Potentiel mauvais payeur")

print("prediction: Potentiel bon payeur")
# Out:
# prediction: Potentiel bon payeur

# %%
url = "http://api-oc.certifyed.io/predict"

querystring = {"num_client":10}

response = requests.post(url, params=querystring)

#response_data = response.json()
#response_data

response
# Out:
# <Response [502]>
