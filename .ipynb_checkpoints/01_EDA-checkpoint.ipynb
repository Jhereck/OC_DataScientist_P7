# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter

import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
df = pd.read_csv("./input/cleaned.csv")
df
# Out:
#         Unnamed: 0  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      100002       1            0             0
# 1                1      100003       0            1             0
# 2                2      100004       0            0             1
# 3                3      100006       0            1             0
# 4                4      100007       0            0             0
# ...            ...         ...     ...          ...           ...
# 307502      307506      456251       0            0             0
# 307503      307507      456252       0            1             0
# 307504      307508      456253       0            1             0
# 307505      307509      456254       1            1             0
# 307506      307510      456255       0            1             0
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0                     0             0          202500.0    406597.5
# 1                     1             0          270000.0   1293502.5
# 2                     0             0           67500.0    135000.0
# 3                     0             0          135000.0    312682.5
# 4                     0             0          121500.0    513000.0
# ...                 ...           ...               ...         ...
# 307502                1             0          157500.0    254700.0
# 307503                0             0           72000.0    269550.0
# 307504                0             0          153000.0    677664.0
# 307505                0             0          171000.0    370107.0
# 307506                1             0          157500.0    675000.0
#
#         AMT_ANNUITY  ...  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0           24700.5  ...                                 NaN
# 1           35698.5  ...                                 NaN
# 2            6750.0  ...                                 NaN
# 3           29686.5  ...                               False
# 4           21865.5  ...                                 NaN
# ...             ...  ...                                 ...
# 307502      27558.0  ...                                 NaN
# 307503      12001.5  ...                                 NaN
# 307504      29979.0  ...                                 NaN
# 307505      20205.0  ...                                 NaN
# 307506      49117.5  ...                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       0.0
# 4                                       NaN
# ...                                     ...
# 307502                                  NaN
# 307503                                  NaN
# 307504                                  NaN
# 307505                                  NaN
# 307506                                  NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      0.0
# 4                                      NaN
# ...                                    ...
# 307502                                 NaN
# 307503                                 NaN
# 307504                                 NaN
# 307505                                 NaN
# 307506                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_NAME_CONTRACT_STATUS_nan_MIN  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      0.0                            False
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 307502                                 NaN                              NaN
# 307503                                 NaN                              NaN
# 307504                                 NaN                              NaN
# 307505                                 NaN                              NaN
# 307506                                 NaN                              NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_MAX  CC_NAME_CONTRACT_STATUS_nan_MEAN  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                 False                               0.0
# 4                                   NaN                               NaN
# ...                                 ...                               ...
# 307502                              NaN                               NaN
# 307503                              NaN                               NaN
# 307504                              NaN                               NaN
# 307505                              NaN                               NaN
# 307506                              NaN                               NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_SUM  CC_NAME_CONTRACT_STATUS_nan_VAR  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   0.0                              0.0
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 307502                              NaN                              NaN
# 307503                              NaN                              NaN
# 307504                              NaN                              NaN
# 307505                              NaN                              NaN
# 307506                              NaN                              NaN
#
#         CC_COUNT
# 0            NaN
# 1            NaN
# 2            NaN
# 3            6.0
# 4            NaN
# ...          ...
# 307502       NaN
# 307503       NaN
# 307504       NaN
# 307505       NaN
# 307506       NaN
#
# [307507 rows x 798 columns]

# %%
df = df.sample(n=16000, random_state=42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16000 entries, 232923 to 120801
# Columns: 798 entries, Unnamed: 0 to CC_COUNT
# dtypes: bool(133), float64(605), int64(44), object(16)
# memory usage: 83.3+ MB

# %%
df.isna().sum()
# Out:
# Unnamed: 0                              0
# SK_ID_CURR                              0
# TARGET                                  0
# CODE_GENDER                             0
# FLAG_OWN_CAR                            0
#                                     ...
# CC_NAME_CONTRACT_STATUS_nan_MAX     11493
# CC_NAME_CONTRACT_STATUS_nan_MEAN    11493
# CC_NAME_CONTRACT_STATUS_nan_SUM     11493
# CC_NAME_CONTRACT_STATUS_nan_VAR     11526
# CC_COUNT                            11493
# Length: 798, dtype: int64

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['AMT_GOODS_PRICE', 'DAYS_EMPLOYED', 'OWN_CAR_AGE', 'EXT_SOURCE_1',
#        'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG',
#        'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG',
#        ...
#        'CC_NAME_CONTRACT_STATUS_Signed_MAX',
#        'CC_NAME_CONTRACT_STATUS_Signed_MEAN',
#        'CC_NAME_CONTRACT_STATUS_Signed_SUM',
#        'CC_NAME_CONTRACT_STATUS_Signed_VAR', 'CC_NAME_CONTRACT_STATUS_nan_MIN',
#        'CC_NAME_CONTRACT_STATUS_nan_MAX', 'CC_NAME_CONTRACT_STATUS_nan_MEAN',
#        'CC_NAME_CONTRACT_STATUS_nan_SUM', 'CC_NAME_CONTRACT_STATUS_nan_VAR',
#        'CC_COUNT'],
#       dtype='object', length=610)

# %%
sns.histplot(df['TARGET'])
# Out:
# <Axes: xlabel='TARGET', ylabel='Count'>

# %%
X = df.copy()
X.drop(columns='TARGET', inplace=True)
y = df['TARGET']
X.drop(columns = ['Unnamed: 0', 'SK_ID_CURR'], inplace=True)
X
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 232923            1             0                0             2
# 263698            1             0                1             0
# 36463             0             0                1             0
# 279380            0             1                0             0
# 148324            1             0                0             0
# ...             ...           ...              ...           ...
# 184039            1             0                1             0
# 57976             1             1                0             1
# 208741            1             0                1             0
# 213022            1             0                0             0
# 120801            0             0                0             0
#
#         AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 232923           72000.0    198666.0      15696.0         175500.0
# 263698          221400.0    247500.0       9814.5         247500.0
# 36463           360000.0    521136.0      54855.0         495000.0
# 279380          360000.0    824917.5      39816.0         724500.0
# 148324          135000.0    628114.5      22689.0         477000.0
# ...                  ...         ...          ...              ...
# 184039           90000.0    270000.0      18783.0         270000.0
# 57976            81000.0    904500.0      26577.0         904500.0
# 208741           67500.0    241618.5      23895.0         229500.0
# 213022          247500.0    582804.0      31747.5         463500.0
# 120801           99900.0    254700.0      24192.0         225000.0
#
#         REGION_POPULATION_RELATIVE  DAYS_BIRTH  ...  \
# 232923                    0.025164       -9267  ...
# 263698                    0.015221      -10916  ...
# 36463                     0.046220      -10066  ...
# 279380                    0.046220      -18698  ...
# 148324                    0.018801      -18162  ...
# ...                            ...         ...  ...
# 184039                    0.026392       -9182  ...
# 57976                     0.025164      -15001  ...
# 208741                    0.024610      -17731  ...
# 213022                    0.006629      -21967  ...
# 120801                    0.006008      -21002  ...
#
#         CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 232923                                 NaN
# 263698                                 NaN
# 36463                                  NaN
# 279380                                 NaN
# 148324                                 NaN
# ...                                    ...
# 184039                                 NaN
# 57976                                  NaN
# 208741                                 NaN
# 213022                                 NaN
# 120801                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 232923                                  NaN
# 263698                                  NaN
# 36463                                   NaN
# 279380                                  NaN
# 148324                                  NaN
# ...                                     ...
# 184039                                  NaN
# 57976                                   NaN
# 208741                                  NaN
# 213022                                  NaN
# 120801                                  NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 232923                                 NaN
# 263698                                 NaN
# 36463                                  NaN
# 279380                                 NaN
# 148324                                 NaN
# ...                                    ...
# 184039                                 NaN
# 57976                                  NaN
# 208741                                 NaN
# 213022                                 NaN
# 120801                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_NAME_CONTRACT_STATUS_nan_MIN  \
# 232923                                 NaN                              NaN
# 263698                                 NaN                              NaN
# 36463                                  NaN                              NaN
# 279380                                 NaN                              NaN
# 148324                                 NaN                              NaN
# ...                                    ...                              ...
# 184039                                 NaN                              NaN
# 57976                                  NaN                              NaN
# 208741                                 NaN                              NaN
# 213022                                 NaN                              NaN
# 120801                                 NaN                              NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_MAX  CC_NAME_CONTRACT_STATUS_nan_MEAN  \
# 232923                              NaN                               NaN
# 263698                              NaN                               NaN
# 36463                               NaN                               NaN
# 279380                              NaN                               NaN
# 148324                              NaN                               NaN
# ...                                 ...                               ...
# 184039                              NaN                               NaN
# 57976                               NaN                               NaN
# 208741                              NaN                               NaN
# 213022                              NaN                               NaN
# 120801                              NaN                               NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_SUM  CC_NAME_CONTRACT_STATUS_nan_VAR  \
# 232923                              NaN                              NaN
# 263698                              NaN                              NaN
# 36463                               NaN                              NaN
# 279380                              NaN                              NaN
# 148324                              NaN                              NaN
# ...                                 ...                              ...
# 184039                              NaN                              NaN
# 57976                               NaN                              NaN
# 208741                              NaN                              NaN
# 213022                              NaN                              NaN
# 120801                              NaN                              NaN
#
#         CC_COUNT
# 232923       NaN
# 263698       NaN
# 36463        NaN
# 279380       NaN
# 148324       NaN
# ...          ...
# 184039       NaN
# 57976        NaN
# 208741       NaN
# 213022       NaN
# 120801       NaN
#
# [16000 rows x 795 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
X_train.fillna(-1, inplace=True)
X_test.fillna(-1, inplace=True)

# %%
scaler = std_scale = preprocessing.StandardScaler()
X_train_knn = scaler.fit_transform(X_train)
X_test_knn = scaler.transform(X_test)
X_train_knn
# Out:
# array([[-1.40836227,  1.38690975, -0.6760217 , ...,  1.60463341,
#          1.61285033,  3.57885333],
#        [ 0.71004458, -0.72102745, -0.6760217 , ..., -0.6231953 ,
#         -0.62002034, -0.42984674],
#        [ 0.71004458, -0.72102745, -0.6760217 , ..., -0.6231953 ,
#         -0.62002034, -0.42984674],
#        ...,
#        [ 0.71004458, -0.72102745, -0.6760217 , ..., -0.6231953 ,
#         -0.62002034, -0.42984674],
#        [ 0.71004458, -0.72102745, -0.6760217 , ..., -0.6231953 ,
#         -0.62002034, -0.42984674],
#        [ 0.71004458, -0.72102745,  1.47924246, ..., -0.6231953 ,
#         -0.62002034, -0.42984674]])

# %% [markdown]
# ## Functions

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, auc, make_scorer, recall_score, accuracy_score, precision_score, confusion_matrix, f1_score, ConfusionMatrixDisplay, classification_report

# %%
# Function to display confusion matrix
def display_confusion_matrix(y_test, y_pred, model_name="Model"):
    ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
    plt.title(model_name + ": Confusion matrix")
    plt.grid(visible=None)
    plt.show()

# %%
# Function to compute roc curve
def compute_roc_curve(y_test, y_pred_proba, model_name="Model", disp_best_th=False):
    # Compute metrics
    fpr, tpr, thresholds = roc_curve(y_test,  y_pred_proba)
    auc = roc_auc_score(y_test, y_pred_proba)
    
    # Create fig
    plt.figure()
    plt.title(model_name + ": ROC curve")

    # Display x=y
    sns.lineplot(x=[0, 1], y=[0, 1], linestyle='--')

    # Display ROC curve
    sns.lineplot(x=fpr, y=tpr, legend='brief', label="AUC = {:.3f}".format((auc)))

    if disp_best_th is True:
        # Compute best threshold
        o_tpr = tpr[np.argmin(np.abs(fpr+tpr-1))]
        o_fpr = fpr[np.argmin(np.abs(fpr+tpr-1))]
        o_threshold = thresholds[np.argmin(np.abs(fpr+tpr-1))]

        # Display best threshold
        sns.scatterplot(x=[o_fpr], y=[o_tpr], legend='brief', label="Best threshold = {:.3f}".format(o_threshold))

    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.legend(loc=4)
    plt.show()

    # Return AUC score
    return auc

# %% [markdown]
# ### Fonction métier

# %%
def cout_custom(y_test, y_pred):  
    tp, fp, fn, tn = confusion_matrix(y_test, y_pred).ravel()
    cost = (10*fp + tp) / len(y_test)
    return float(cost)

# %%
# Create business score
business_score = make_scorer(cout_custom, greater_is_better=False)

# %%
# Function to compute predictions and metrics
def compute_classification_results(model, model_name, x_test, y_test):

    # Predict probability of class 1 (repay failure)
    y_pred_proba = model.predict_proba(x_test)[:,1]

    # Predict values 
    y_pred = model.predict(x_test)

    # Display confusion matrix
    display_confusion_matrix(y_test, y_pred, model_name=model_name)

    # Draw roc curve
    auc_score = compute_roc_curve(y_test, y_pred_proba, model_name=model_name)

    # Compute scores
    clf_report = pd.DataFrame(classification_report(y_test, y_pred, output_dict=True)).transpose()
    display(clf_report)

    # Display business loss func
    business_score = cout_custom(y_test, y_pred)
    print("Business score =", business_score)

    return business_score, auc_score, clf_report

# %% [markdown]
# ## MlFlow

# %%
import mlflow
from mlflow import log_metric, log_param, log_artifacts

# Create experiment
experiment_name = 'credit_scoring'
mlflow.set_experiment(experiment_name)
mlflow.end_run()

# %%
# Function to log model to mlflow
def log_mlflow(model, name, custom_score, n_estimator=None, max_depth=None, auc_score=None, f1_score=None, acc_score=None,
               train_class_0=None, train_class_1=None):

    # Track params and metrics 
    with mlflow.start_run():
        # Set run name
        mlflow.set_tag("mlflow.runName", name)

        # Set parameters
        mlflow.log_param("n_estimators", n_estimator)
        mlflow.log_param("max_depth", max_depth)
        mlflow.log_param("train_class_0", train_class_0)
        mlflow.log_param("train_class_1", train_class_1)

        # Set metrics
        mlflow.log_metric("Custom score", custom_score)
        mlflow.log_metric("AUC", auc_score)
        mlflow.log_metric("F1", f1_score)
        mlflow.log_metric("Accuracy", acc_score)

        # Save model to artifacts
        mlflow.sklearn.log_model(model, name)

    mlflow.end_run()

# %% [markdown]
# ## DummyClassifier

# %%
from sklearn.dummy import DummyClassifier

# %%
# Create logistic regression model
dc = DummyClassifier(strategy='stratified', random_state=42)
dc_name = 'DummyClassifier'

# Fit model
dc.fit(X_train_knn, y_train)

# Compute results
dc_business_score, dc_auc, dc_report = compute_classification_results(dc, dc_name, X_test_knn, y_test)

# Save logs
log_mlflow(dc, dc_name, auc_score=dc_auc, custom_score=dc_business_score,
           f1_score=dc_report.loc['weighted avg', 'f1-score'], 
           acc_score=dc_report.loc['accuracy', 'precision'],
           train_class_0=Counter(y_train)[0], train_class_1=Counter(y_train)[1])
# Out:
#               precision    recall  f1-score      support
# 0              0.918839  0.918839  0.918839  4411.000000
# 1              0.079692  0.079692  0.079692   389.000000
# accuracy       0.850833  0.850833  0.850833     0.850833
# macro avg      0.499265  0.499265  0.499265  4800.000000
# weighted avg   0.850833  0.850833  0.850833  4800.000000
# Business score = 1.5902083333333332

# %%
from sklearn.linear_model import LogisticRegression

# %%
# %%time

# Create logistic regression model
lr = LogisticRegression(class_weight='balanced')
lr_name = 'LogisticRegression'

# Train model
lr.fit(X_train_knn, y_train)

# Compute results
lr_business_score, lr_auc, lr_report = compute_classification_results(lr, lr_name, X_test_knn, y_test)

# Save logs
log_mlflow(lr, lr_name, auc_score=lr_auc, custom_score=lr_business_score,
           f1_score=lr_report.loc['weighted avg', 'f1-score'], 
           acc_score=lr_report.loc['accuracy', 'precision'],
           train_class_0=Counter(y_train)[0], train_class_1=Counter(y_train)[1])
# Out:
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score      support
# 0              0.952185  0.735888  0.830179  4411.000000
# 1              0.162473  0.580977  0.253933   389.000000
# accuracy       0.723333  0.723333  0.723333     0.723333
# macro avg      0.557329  0.658432  0.542056  4800.000000
# weighted avg   0.888186  0.723333  0.783479  4800.000000
# Business score = 3.1033333333333335
# CPU times: total: 1.81 s
# Wall time: 7.28 s

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# %%time

# Create random forest classifier
rf = RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1)
rf_name = 'RandomForest'

# Train model
rf.fit(X_train_knn, y_train)

# Compute results
rf_business_score, rf_auc, rf_report = compute_classification_results(rf, rf_name, X_test_knn, y_test)

# Save logs
rf_params = rf.get_params()
log_mlflow(rf, rf_name,
           custom_score=rf_business_score,
           auc_score=rf_auc,
           f1_score=rf_report.loc['weighted avg', 'f1-score'], 
           acc_score=rf_report.loc['accuracy', 'precision'],
           n_estimator=rf_params['n_estimators'],
           max_depth=rf_params['max_depth'], 
           train_class_0=Counter(y_train)[0],
           train_class_1=Counter(y_train)[1])
# Out:
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score      support
# 0              0.918958  1.000000  0.957768  4411.000000
# 1              0.000000  0.000000  0.000000   389.000000
# accuracy       0.918958  0.918958  0.918958     0.918958
# macro avg      0.459479  0.500000  0.478884  4800.000000
# weighted avg   0.844484  0.918958  0.880149  4800.000000
# Business score = 0.9189583333333333
# CPU times: total: 7.58 s
# Wall time: 4.4 s

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# %%time

# Create random forest classifier
dt = DecisionTreeClassifier(class_weight='balanced', random_state=42)
dt_name = 'DecisionTree'

# Train model
dt.fit(X_train_knn, y_train)

# Compute results
dt_business_score, dt_auc, dt_report = compute_classification_results(dt, dt_name, X_test_knn, y_test)

# Save logs
dt_params = dt.get_params()
log_mlflow(dt, dt_name,
           custom_score=dt_business_score,
           auc_score=dt_auc,
           f1_score=dt_report.loc['weighted avg', 'f1-score'], 
           acc_score=dt_report.loc['accuracy', 'precision'],
           max_depth=dt_params['max_depth'], 
           train_class_0=Counter(y_train)[0],
           train_class_1=Counter(y_train)[1])
# Out:
#               precision    recall  f1-score      support
# 0              0.923970  0.920200  0.922081  4411.000000
# 1              0.135135  0.141388  0.138191   389.000000
# accuracy       0.857083  0.857083  0.857083     0.857083
# macro avg      0.529553  0.530794  0.530136  4800.000000
# weighted avg   0.860041  0.857083  0.858553  4800.000000
# Business score = 1.5789583333333332
# CPU times: total: 1.36 s
# Wall time: 7.08 s

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
# %%time

# Create XGBoost classifier
hgbc = HistGradientBoostingClassifier(class_weight='balanced', random_state=42)
hgbc_name = 'HistGradientBoostingClassifier'

# Train model
hgbc.fit(X_train_knn, y_train)

# Compute results
hgbc_business_score, hgbc_auc, hgbc_report = compute_classification_results(hgbc, hgbc_name, X_test_knn, y_test)

# Save logs
hgbc_params = hgbc.get_params()
log_mlflow(hgbc, hgbc_name,
           custom_score=hgbc_business_score,
           auc_score=hgbc_auc,
           f1_score=hgbc_report.loc['weighted avg', 'f1-score'], 
           acc_score=hgbc_report.loc['accuracy', 'precision'],
           max_depth=hgbc_params['max_depth'], 
           train_class_0=Counter(y_train)[0],
           train_class_1=Counter(y_train)[1])
# Out:
#               precision    recall  f1-score  support
# 0              0.946442  0.829290  0.884002   4411.0
# 1              0.194652  0.467866  0.274924    389.0
# accuracy       0.800000  0.800000  0.800000      0.8
# macro avg      0.570547  0.648578  0.579463   4800.0
# weighted avg   0.885516  0.800000  0.834641   4800.0
# Business score = 2.3308333333333335
# CPU times: total: 10.5 s
# Wall time: 14.7 s

# %% [markdown]
# ## Hyperparametrisation

# %%
param_grid = {'n_estimators': range(100, 250, 50), 'min_samples_leaf': np.arange(1, 3, 1)}

mes = {"AUC": "roc_auc", "Acc": "accuracy", "Precision": "precision", "Metier" : business_score}

rdfh = model_selection.GridSearchCV(
    RandomForestClassifier(class_weight='balanced', random_state=42), # un classifieur kNN
    param_grid,     # hyperparamètres à tester
    cv=5,           # nombre de folds de validation croisée
    n_jobs=-1,           # nombre de folds de validation croisée
    scoring=mes,
    refit='Metier',
    return_train_score=True,
)

# Optimiser ce classifieur sur le jeu d'entraînement
rdfh.fit(X_train_knn, y_train)

# Afficher le(s) hyperparamètre(s) optimaux
print("Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:")
print(rdfh.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, prec, banc, params in zip(
        rdfh.cv_results_['mean_test_AUC'], # score moyen
        rdfh.cv_results_['mean_test_Acc'],  # écart-type du score
        rdfh.cv_results_['mean_test_Precision'],
        rdfh.cv_results_['mean_test_Metier'],
        rdfh.cv_results_['params']           # valeur de l'hyperparamètre
    ):

    print("AUC = {:.3f}, acc = {:.03f}, prec = {:.03f}, métier = {:.01f} for {}".format(
        mean,
        std,
        prec,
        banc,
        params
    ) )
# Out:
# Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:
# {'min_samples_leaf': 2, 'n_estimators': 100}
# Résultats de la validation croisée :
# AUC = 0.692, acc = 0.917, prec = 0.100, métier = -0.9 for {'min_samples_leaf': 1, 'n_estimators': 100}
# AUC = 0.707, acc = 0.916, prec = 0.000, métier = -0.9 for {'min_samples_leaf': 1, 'n_estimators': 150}
# AUC = 0.715, acc = 0.916, prec = 0.000, métier = -0.9 for {'min_samples_leaf': 1, 'n_estimators': 200}
# AUC = 0.703, acc = 0.917, prec = 0.400, métier = -0.9 for {'min_samples_leaf': 2, 'n_estimators': 100}
# AUC = 0.715, acc = 0.917, prec = 0.400, métier = -0.9 for {'min_samples_leaf': 2, 'n_estimators': 150}
# AUC = 0.720, acc = 0.917, prec = 0.400, métier = -0.9 for {'min_samples_leaf': 2, 'n_estimators': 200}

# %%
# %%time

# Create random forest classifier
rf2 = RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1)
rf2_name = 'RandomForest'

# Train model
rf2.fit(X_train_knn, y_train)

# Compute results
rf2_business_score, rf2_auc, rf2_report = compute_classification_results(rf2, rf2_name, X_test_knn, y_test)

# Save logs
rf2_params = rf2.get_params()
log_mlflow(rf2, rf2_name,
           custom_score=rf2_business_score,
           auc_score=rf2_auc,
           f1_score=rf2_report.loc['weighted avg', 'f1-score'], 
           acc_score=rf2_report.loc['accuracy', 'precision'],
           n_estimator=rf2_params['n_estimators'],
           max_depth=rf2_params['max_depth'], 
           train_class_0=Counter(y_train)[0],
           train_class_1=Counter(y_train)[1])
# Out:
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\dar55\.virtualenvs\Data_Scientist-FqGbSdFt\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score      support
# 0              0.918958  1.000000  0.957768  4411.000000
# 1              0.000000  0.000000  0.000000   389.000000
# accuracy       0.918958  0.918958  0.918958     0.918958
# macro avg      0.459479  0.500000  0.478884  4800.000000
# weighted avg   0.844484  0.918958  0.880149  4800.000000
# Business score = 0.9189583333333333
# CPU times: total: 7.78 s
# Wall time: 4.71 s

# %%
predict_rf = rf.predict_proba(y_test)
predict_rf = predict_rf[:,1]
fpr, tpr, thresholds = roc_curve(y_test, predict_rf)
J = tpr - fpr
ix = argmax(J)
best_thresh = thersholds[ix]
print("Meilleur threshold = f'{best_thresh}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 predict_rf2 = rf.predict_proba(y_test)
#       2 predict_rf2 = predict_rf2[:,1]
#       3 fpr, tpr, thresholds = roc_curve(y_test, predict_rf2)
#
# NameError: name 'rf' is not defined

# %%
param_grid = {'max_leaf_nodes': np.arange(2, 6, 1), 'min_samples_leaf': np.arange(1, 10, 1)}

mes = {"AUC": "roc_auc", "Acc": "accuracy", "Precision": "precision", "Bancaire" : business_score}

hgbc = model_selection.GridSearchCV(
    HistGradientBoostingClassifier(class_weight='balanced', random_state=42), # un classifieur kNN
    param_grid,     # hyperparamètres à tester
    cv=5,
    n_jobs=-1,           # nombre de folds de validation croisée
    scoring=mes,
    refit='Bancaire',
    return_train_score=True,
)

# Optimiser ce classifieur sur le jeu d'entraînement
hgbc.fit(X_train_knn, y_train)

# Afficher le(s) hyperparamètre(s) optimaux
print("Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:")
print(hgbc.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, prec, banc, params in zip(
        hgbc.cv_results_['mean_test_AUC'], # score moyen
        hgbc.cv_results_['mean_test_Acc'],  # écart-type du score
        hgbc.cv_results_['mean_test_Precision'],
        hgbc.cv_results_['mean_test_Bancaire'],
        hgbc.cv_results_['params']           # valeur de l'hyperparamètre
    ):

    print("AUC = {:.3f}, acc = {:.03f}, prec = {:.03f}, banc = {:.01f} for {}".format(
        mean,
        std,
        prec,
        banc,
        params
    ) )
# Out:
# Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:
# {'max_leaf_nodes': 5, 'min_samples_leaf': 5}
# Résultats de la validation croisée :
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 1}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 2}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 3}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 4}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 5}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 6}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 7}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 8}
# AUC = 0.749, acc = 0.704, prec = 0.174, banc = -3.3 for {'max_leaf_nodes': 2, 'min_samples_leaf': 9}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 1}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 2}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 3}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 4}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 5}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 6}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 7}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 8}
# AUC = 0.756, acc = 0.724, prec = 0.182, banc = -3.1 for {'max_leaf_nodes': 3, 'min_samples_leaf': 9}
# AUC = 0.757, acc = 0.740, prec = 0.188, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 1}
# AUC = 0.756, acc = 0.740, prec = 0.188, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 2}
# AUC = 0.756, acc = 0.740, prec = 0.188, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 3}
# AUC = 0.756, acc = 0.740, prec = 0.188, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 4}
# AUC = 0.756, acc = 0.739, prec = 0.187, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 5}
# AUC = 0.757, acc = 0.739, prec = 0.187, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 6}
# AUC = 0.757, acc = 0.740, prec = 0.187, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 7}
# AUC = 0.757, acc = 0.740, prec = 0.188, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 8}
# AUC = 0.758, acc = 0.740, prec = 0.188, banc = -3.0 for {'max_leaf_nodes': 4, 'min_samples_leaf': 9}
# AUC = 0.756, acc = 0.749, prec = 0.190, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 1}
# AUC = 0.756, acc = 0.749, prec = 0.190, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 2}
# AUC = 0.757, acc = 0.749, prec = 0.191, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 3}
# AUC = 0.756, acc = 0.749, prec = 0.191, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 4}
# AUC = 0.758, acc = 0.750, prec = 0.191, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 5}
# AUC = 0.757, acc = 0.750, prec = 0.191, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 6}
# AUC = 0.757, acc = 0.749, prec = 0.189, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 7}
# AUC = 0.756, acc = 0.749, prec = 0.190, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 8}
# AUC = 0.756, acc = 0.749, prec = 0.190, banc = -2.9 for {'max_leaf_nodes': 5, 'min_samples_leaf': 9}

# %%
# %%time

# Create random forest classifier
hgbc2 = HistGradientBoostingClassifier(max_leaf_nodes=5, min_samples_leaf=5, class_weight='balanced', random_state=42)
hgbc2_name = 'HistGradientBoostingClassifier'

# Train model
hgbc2.fit(X_train_knn, y_train)

# Compute results
hgbc2_business_score, hgbc2_auc, hgbc2_report = compute_classification_results(hgbc2, hgbc2_name, X_test_knn, y_test)

# Save logs
hgbc2_params = hgbc2.get_params()
log_mlflow(hgbc2, hgbc2_name,
           custom_score=hgbc2_business_score,
           auc_score=hgbc2_auc,
           f1_score=hgbc2_report.loc['weighted avg', 'f1-score'], 
           acc_score=hgbc2_report.loc['accuracy', 'precision'],
           max_depth=hgbc2_params['max_depth'], 
           train_class_0=Counter(y_res)[0],
           train_class_1=Counter(y_res)[1])
# Out:
#               precision    recall  f1-score      support
# 0              0.954802  0.766266  0.850208  4411.000000
# 1              0.181746  0.588689  0.277744   389.000000
# accuracy       0.751875  0.751875  0.751875     0.751875
# macro avg      0.568274  0.677478  0.563976  4800.000000
# weighted avg   0.892152  0.751875  0.803814  4800.000000
# Business score = 2.8520833333333333
# CPU times: total: 7.12 s
# Wall time: 8.92 s

# %%
param_grid = {'n_neighbors':[500, 700, 800, 900, 950, 1000, 1050, 1100, 1200, 1300, 1400], 'weights':['uniform', 'distance']}

mes = {"AUC": "roc_auc", "Acc": "accuracy", "Precision": "precision", "Bancaire" : make_scorer(cout_custom, greater_is_better=False)}

clf = model_selection.GridSearchCV(
    KNeighborsClassifier(), # un classifieur kNN
    param_grid,     # hyperparamètres à tester
    cv=5,           # nombre de folds de validation croisée
    n_jobs=-1,           # nombre de folds de validation croisée
    scoring=mes,
    refit='Bancaire',
    return_train_score=True,
)

# Optimiser ce classifieur sur le jeu d'entraînement
clf.fit(X_train_knn, y_train)

# Afficher le(s) hyperparamètre(s) optimaux
print("Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:")
print(clf.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, prec, banc, params in zip(
        clf.cv_results_['mean_test_AUC'], # score moyen
        clf.cv_results_['mean_test_Acc'],  # écart-type du score
        clf.cv_results_['mean_test_Precision'],
        clf.cv_results_['mean_test_Bancaire'],
        clf.cv_results_['params']           # valeur de l'hyperparamètre
    ):

    print("AUC = {:.3f}, acc = {:.03f}, prec = {:.03f}, banc = {:.01f} for {}".format(
        mean,
        std,
        prec,
        banc,
        params
    ) )
# Out:
# Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:
# {'n_neighbors': 500, 'weights': 'uniform'}
# Résultats de la validation croisée :
# AUC = 0.648, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 500, 'weights': 'uniform'}
# AUC = 0.649, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 500, 'weights': 'distance'}
# AUC = 0.651, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 700, 'weights': 'uniform'}
# AUC = 0.651, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 700, 'weights': 'distance'}
# AUC = 0.655, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 800, 'weights': 'uniform'}
# AUC = 0.655, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 800, 'weights': 'distance'}
# AUC = 0.659, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 900, 'weights': 'uniform'}
# AUC = 0.658, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 900, 'weights': 'distance'}
# AUC = 0.662, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 950, 'weights': 'uniform'}
# AUC = 0.661, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 950, 'weights': 'distance'}
# AUC = 0.662, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1000, 'weights': 'uniform'}
# AUC = 0.662, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1000, 'weights': 'distance'}
# AUC = 0.663, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1050, 'weights': 'uniform'}
# AUC = 0.663, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1050, 'weights': 'distance'}
# AUC = 0.660, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1100, 'weights': 'uniform'}
# AUC = 0.660, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1100, 'weights': 'distance'}
# AUC = 0.657, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1200, 'weights': 'uniform'}
# AUC = 0.658, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1200, 'weights': 'distance'}
# AUC = 0.655, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1300, 'weights': 'uniform'}
# AUC = 0.656, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1300, 'weights': 'distance'}
# AUC = 0.657, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1400, 'weights': 'uniform'}
# AUC = 0.657, acc = 0.917, prec = 0.000, banc = -1870.0 for {'n_neighbors': 1400, 'weights': 'distance'}

# %%
param_grid = {'min_samples_split': range(2000, 3600, 100)}

mes = {"AUC": "roc_auc", "Acc": "accuracy", "Precision": "precision", "Bancaire" : make_scorer(cout_custom, greater_is_better=False)}

tree = model_selection.GridSearchCV(
    DecisionTreeClassifier(class_weight='balanced'), # un classifieur kNN
    param_grid,     # hyperparamètres à tester
    cv=5,
    n_jobs=-1,           # nombre de folds de validation croisée
    scoring=mes,
    refit='Bancaire',
    return_train_score=True,
)

# Optimiser ce classifieur sur le jeu d'entraînement
tree.fit(X_train_knn, y_train)

# Afficher le(s) hyperparamètre(s) optimaux
print("Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:")
print(tree.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, prec, banc, params in zip(
        tree.cv_results_['mean_test_AUC'], # score moyen
        tree.cv_results_['mean_test_Acc'],  # écart-type du score
        tree.cv_results_['mean_test_Precision'],
        tree.cv_results_['mean_test_Bancaire'],
        tree.cv_results_['params']           # valeur de l'hyperparamètre
    ):

    print("AUC = {:.3f}, acc = {:.03f}, prec = {:.03f}, banc = {:.01f} for {}".format(
        mean,
        std,
        prec,
        banc,
        params
    ) )
# Out:
# Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:
# {'min_samples_split': 2400}
# Résultats de la validation croisée :
# AUC = 0.682, acc = 0.691, prec = 0.150, banc = -1433.0 for {'min_samples_split': 2000}
# AUC = 0.684, acc = 0.666, prec = 0.146, banc = -1427.0 for {'min_samples_split': 2100}
# AUC = 0.685, acc = 0.668, prec = 0.148, banc = -1415.8 for {'min_samples_split': 2200}
# AUC = 0.684, acc = 0.669, prec = 0.148, banc = -1417.2 for {'min_samples_split': 2300}
# AUC = 0.679, acc = 0.759, prec = 0.174, banc = -1378.8 for {'min_samples_split': 2400}
# AUC = 0.679, acc = 0.759, prec = 0.174, banc = -1378.8 for {'min_samples_split': 2500}
# AUC = 0.679, acc = 0.759, prec = 0.174, banc = -1378.8 for {'min_samples_split': 2600}
# AUC = 0.681, acc = 0.759, prec = 0.174, banc = -1378.8 for {'min_samples_split': 2700}
# AUC = 0.679, acc = 0.759, prec = 0.174, banc = -1380.6 for {'min_samples_split': 2800}
# AUC = 0.677, acc = 0.764, prec = 0.175, banc = -1386.0 for {'min_samples_split': 2900}
# AUC = 0.677, acc = 0.764, prec = 0.175, banc = -1386.0 for {'min_samples_split': 3000}
# AUC = 0.677, acc = 0.764, prec = 0.175, banc = -1386.0 for {'min_samples_split': 3100}
# AUC = 0.676, acc = 0.765, prec = 0.176, banc = -1384.6 for {'min_samples_split': 3200}
# AUC = 0.676, acc = 0.765, prec = 0.176, banc = -1384.6 for {'min_samples_split': 3300}
# AUC = 0.672, acc = 0.739, prec = 0.169, banc = -1392.2 for {'min_samples_split': 3400}
# AUC = 0.663, acc = 0.688, prec = 0.150, banc = -1428.6 for {'min_samples_split': 3500}

# %%
param_grid = {'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']}

mes = {"AUC": "roc_auc", "Acc": "accuracy", "Precision": "precision", "Bancaire" : make_scorer(cout_custom, greater_is_better=False)}

log_reg = model_selection.GridSearchCV(
    LogisticRegression(class_weight='balanced', max_iter=300), # un classifieur kNN
    param_grid,     # hyperparamètres à tester
    cv=5,
    n_jobs=-1,           # nombre de folds de validation croisée
    scoring=mes,
    refit='Bancaire',
    return_train_score=True,
)

# Optimiser ce classifieur sur le jeu d'entraînement
log_reg.fit(X_train_knn, y_train)

# Afficher le(s) hyperparamètre(s) optimaux
print("Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:")
print(log_reg.best_params_)

# Afficher les performances correspondantes
print("Résultats de la validation croisée :")
for mean, std, prec, banc, params in zip(
        log_reg.cv_results_['mean_test_AUC'], # score moyen
        log_reg.cv_results_['mean_test_Acc'],  # écart-type du score
        log_reg.cv_results_['mean_test_Precision'],
        log_reg.cv_results_['mean_test_Bancaire'],
        log_reg.cv_results_['params']           # valeur de l'hyperparamètre
    ):

    print("AUC = {:.3f}, acc = {:.03f}, prec = {:.03f}, banc = {:.01f} for {}".format(
        mean,
        std,
        prec,
        banc,
        params
    ) )
# Out:
# Meilleur(s) hyperparamètre(s) sur le jeu d'entraînement:
# {'solver': 'saga'}
# Résultats de la validation croisée :
# AUC = 0.697, acc = 0.726, prec = 0.160, banc = -1388.6 for {'solver': 'lbfgs'}
# AUC = 0.697, acc = 0.725, prec = 0.158, banc = -1404.4 for {'solver': 'liblinear'}
# AUC = 0.697, acc = 0.725, prec = 0.159, banc = -1403.4 for {'solver': 'newton-cg'}
# AUC = 0.697, acc = 0.726, prec = 0.159, banc = -1403.2 for {'solver': 'newton-cholesky'}
# AUC = 0.716, acc = 0.727, prec = 0.170, banc = -1307.2 for {'solver': 'sag'}
# AUC = 0.719, acc = 0.724, prec = 0.171, banc = -1296.8 for {'solver': 'saga'}
# c:\Users\dar55\.virtualenvs\Data_Scientist-U1iC_AqC\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
